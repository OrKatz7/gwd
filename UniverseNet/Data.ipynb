# %%
import mmcv
from mmcv import Config
from mmcv.runner import load_checkpoint
from mmcv.parallel import MMDataParallel
from mmdet.apis import init_detector, inference_detector, show_result_pyplot
from mmdet.models import build_detector
from mmdet.apis import single_gpu_test
from mmdet.datasets import build_dataloader, build_dataset
import cv2
import pandas as pd
import numpy as np
import os
import re
import json

from PIL import Image
import matplotlib.pyplot as plt
import torch

# %% [markdown]
# # csv2coco and 5-flod

# %%
def expand_bbox(x):
    r = np.array(re.findall("([0-9]+[.]?[0-9]*)", x))
    if len(r) == 0:
        r = [-1, -1, -1, -1]
    return r

def marking_pre(csv_file, debug=False):
    df = pd.read_csv(csv_file)
    df['x'] = -1
    df['y'] = -1
    df['w'] = -1
    df['h'] = -1
    
    df[['x', 'y', 'w', 'h']] = np.stack(df['bbox'].apply(lambda x: expand_bbox(x)))
    df.drop(columns=['bbox'], inplace=True)
    df['xmin'] = df['x'].astype(np.float)
    df['ymin'] = df['y'].astype(np.float)
    df['w'] = df['w'].astype(np.float)
    df['h'] = df['h'].astype(np.float)
    df['area'] = df['w']*df['h']
    error_bbox = [100648.0, 145360.0, 149744.0, 119790.0, 106743.0]
    df = df[df['area']<154200.0]
    df = df[~df['area'].isin(error_bbox)]
    df = df[df['w']>=10.0]
    df = df[df['h']>=10.0]
    df['xmax'] = df.apply(lambda x: x['xmin'] + x['w'], axis=1)
    df['ymax'] = df.apply(lambda x: x['ymin'] + x['h'], axis=1)
    df['category'] = 'wheat'
    df['image_id'] = df.apply(lambda x: x['image_id'] + '.jpg', axis=1)
    df.drop(columns=['x', 'y', 'w', 'h','width','height','area'], inplace=True)
    print(df.head())
    if debug:
      df =df[:1500]
    return df

# %%
import glob
import os
import shutil
from IPython import embed
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
np.random.seed(42)

#{"background":1}
classname_to_id = {"wheat": 0}

class Csv2CoCo:

    def __init__(self,image_dir,total_annos):
        self.images = []
        self.annotations = []
        self.categories = []
        self.img_id = 0
        self.ann_id = 0
        self.image_dir = image_dir
        self.total_annos = total_annos

    def save_coco_json(self, instance, save_path):
        json.dump(instance, open(save_path, 'w'), ensure_ascii=False, indent=2)  # indent=2 更加美观显示

    # 由txt文件构建COCO
    def to_coco(self, keys):
        self._init_categories()
        for key in keys:
            self.images.append(self._image(key))
            shapes = self.total_annos[key]
            for shape in shapes:
                bboxi = []
                for cor in shape[:-1]:
                    bboxi.append(int(float(cor)))
                label = shape[-1]
                annotation = self._annotation(bboxi,label)
                self.annotations.append(annotation)
                self.ann_id += 1
            self.img_id += 1
        instance = {}
        instance['info'] = 'OrKatz'
        instance['license'] = ['license']
        instance['images'] = self.images
        instance['annotations'] = self.annotations
        instance['categories'] = self.categories
        return instance

    # 构建类别
    def _init_categories(self):
        for k, v in classname_to_id.items():
            category = {}
            category['id'] = v
            category['name'] = k
            self.categories.append(category)

    # 构建COCO的image字段
    def _image(self, path):
        image = {}
        img_path = self.image_dir + path
        print(img_path)
        img = cv2.imread(img_path)
        image['height'] = img.shape[0]
        image['width'] = img.shape[1]
        image['id'] = self.img_id
        image['file_name'] = path
        return image

    # 构建COCO的annotation字段
    def _annotation(self, shape, label):
        # label = shape[-1]
        points = shape[:4]
        annotation = {}
        annotation['id'] = self.ann_id
        annotation['image_id'] = self.img_id
        annotation['category_id'] = int(classname_to_id[label])
        annotation['segmentation'] = self._get_seg(points)
        annotation['bbox'] = self._get_box(points)
        annotation['iscrowd'] = 0
        annotation['area'] = self._get_area(points)
        return annotation

    # COCO的格式： [x1,y1,w,h] 对应COCO的bbox格式
    def _get_box(self, points):
        min_x = points[0]
        min_y = points[1]
        max_x = points[2]
        max_y = points[3]
        return [min_x, min_y, max_x - min_x, max_y - min_y]
    # 计算面积
    def _get_area(self, points):
        min_x = points[0]
        min_y = points[1]
        max_x = points[2]
        max_y = points[3]
        return (max_x - min_x+1) * (max_y - min_y+1)
    # segmentation
    def _get_seg(self, points):
        min_x = points[0]
        min_y = points[1]
        max_x = points[2]
        max_y = points[3]
        h = max_y - min_y
        w = max_x - min_x
        a = []
        a.append([min_x,min_y, min_x,min_y+0.5*h, min_x,max_y, min_x+0.5*w,max_y, max_x,max_y, max_x,max_y-0.5*h, max_x,min_y, max_x-0.5*w,min_y])
        return a
   
def sk_5fold(marking,fold_number):
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    df_folds = marking[['image_id']].copy()
    df_folds.loc[:, 'bbox_count'] = 1
    df_folds = df_folds.groupby('image_id').count()
    df_folds.loc[:, 'source'] = marking[['image_id', 'source']].groupby('image_id').min()['source']
    df_folds.loc[:, 'stratify_group'] = np.char.add(
        df_folds['source'].values.astype(str),
        df_folds['bbox_count'].apply(lambda x: f'_{x // 15}').values.astype(str)
    )
    df_folds.loc[:, 'fold'] = 0

    for fold_number, (train_index, val_index) in enumerate(skf.split(X=df_folds.index, y=df_folds['stratify_group'])):
        df_folds.loc[df_folds.iloc[val_index].index, 'fold'] = fold_number
    
    return df_folds
    
    
    
def with_5fold_to_coco(csv_file,image_dir,saved_coco_path,fold_number,debug):
    total_csv_annotations = {}
    marking = marking_pre(csv_file, debug)
    
    df_folds = sk_5fold(marking,fold_number)
    train_keys = df_folds[df_folds['fold'] != fold_number].index.values
    val_keys = df_folds[df_folds['fold'] == fold_number].index.values
    
    marking = marking.drop(columns=['source'], axis=1)
    print(marking.head())
    annotations = marking.values
    for annotation in annotations:
        key = annotation[0].split(os.sep)[-1]
        value = np.array([annotation[1:]])
        if key in total_csv_annotations.keys():
            total_csv_annotations[key] = np.concatenate((total_csv_annotations[key],value),axis=0)
        else:
            total_csv_annotations[key] = value
    total_keys = list(total_csv_annotations.keys())
    print("train_n:", len(train_keys), 'val_n:', len(val_keys), 'total_n:', len(total_keys))    
    annotations_path = f'{saved_coco_path}/annotations/'
    train_path = f'{saved_coco_path}/train2017'
    val_path = f'{saved_coco_path}/val2017'
    if not os.path.exists(annotations_path):
        os.makedirs(annotations_path)
    if not os.path.exists(train_path):
        os.makedirs(train_path)
    if not os.path.exists(val_path):
        os.makedirs(val_path)
    l2c_train = Csv2CoCo(image_dir=image_dir,total_annos=total_csv_annotations)
    train_instance = l2c_train.to_coco(train_keys)
    l2c_train.save_coco_json(train_instance, f'{annotations_path}instances_train2017.json')
    for file in train_keys:
        shutil.copy(image_dir+file,train_path)
    for file in val_keys:
        shutil.copy(image_dir+file,val_path)
    l2c_val = Csv2CoCo(image_dir=image_dir,total_annos=total_csv_annotations)
    val_instance = l2c_val.to_coco(val_keys)
    l2c_val.save_coco_json(val_instance, f'{annotations_path}instances_val2017.json')

# %% [markdown]
# # File Path

# %%
csv_file = '../data/train.csv'
image_dir = '../data/train/'
saved_coco_path = './data/train/coco'
fold_number = 0
debug = False

# %% [markdown]
# # Run Data Format Conversion

# %%
with_5fold_to_coco(csv_file,image_dir,saved_coco_path,fold_number,debug)
# Out:
#         image_id   source   xmin   ymin   xmax   ymax category
# 0  b6ab77fd7.jpg  usask_1  834.0  222.0  890.0  258.0    wheat
# 1  b6ab77fd7.jpg  usask_1  226.0  548.0  356.0  606.0    wheat
# 2  b6ab77fd7.jpg  usask_1  377.0  504.0  451.0  664.0    wheat
# 3  b6ab77fd7.jpg  usask_1  834.0   95.0  943.0  202.0    wheat
# 4  b6ab77fd7.jpg  usask_1   26.0  144.0  150.0  261.0    wheat
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#         image_id   xmin   ymin   xmax   ymax category
# 0  b6ab77fd7.jpg  834.0  222.0  890.0  258.0    wheat
# 1  b6ab77fd7.jpg  226.0  548.0  356.0  606.0    wheat
# 2  b6ab77fd7.jpg  377.0  504.0  451.0  664.0    wheat
# 3  b6ab77fd7.jpg  834.0   95.0  943.0  202.0    wheat
# 4  b6ab77fd7.jpg   26.0  144.0  150.0  261.0    wheat
# train_n: 2698 val_n: 675 total_n: 3373
# ../data/train/00333207f.jpg
# ../data/train/005b0d8bb.jpg
# ../data/train/006a994f7.jpg
# ../data/train/00b5fefed.jpg
# ../data/train/00b70a919.jpg
# ../data/train/00ea5e5ee.jpg
# ../data/train/010c93b99.jpg
# ../data/train/010dbcc8f.jpg
# ../data/train/01189a3c3.jpg
# ../data/train/0126b7d11.jpg
# ../data/train/013669953.jpg
# ../data/train/01397a84c.jpg
# ../data/train/013fd7d80.jpg
# ../data/train/015939012.jpg
# ../data/train/0172359d2.jpg
# ../data/train/019d1c76a.jpg
# ../data/train/01f37f1d3.jpg
# ../data/train/02640d9da.jpg
# ../data/train/02992044c.jpg
# ../data/train/029c79463.jpg
# ../data/train/029e03e52.jpg
# ../data/train/02b6f199c.jpg
# ../data/train/02d662fa8.jpg
# ../data/train/02e02e347.jpg
# ../data/train/02f0fe2ca.jpg
# ../data/train/02fe8c28e.jpg
# ../data/train/031ed396f.jpg
# ../data/train/034090252.jpg
# ../data/train/03448724b.jpg
# ../data/train/0352a6fff.jpg
# ../data/train/035bdc07a.jpg
# ../data/train/036cbd683.jpg
# ../data/train/037d96952.jpg
# ../data/train/038432e90.jpg
# ../data/train/03a177626.jpg
# ../data/train/03a242bd2.jpg
# ../data/train/03a988adf.jpg
# ../data/train/03ad2a35c.jpg
# ../data/train/03cae970d.jpg
# ../data/train/03d831c0d.jpg
# ../data/train/041707ba8.jpg
# ../data/train/04201d2d6.jpg
# ../data/train/0424c00e4.jpg
# ../data/train/0429c9ff6.jpg
# ../data/train/043a957ca.jpg
# ../data/train/044078e70.jpg
# ../data/train/044097f45.jpg
# ../data/train/045d846eb.jpg
# ../data/train/0478cbc2a.jpg
# ../data/train/04981ca30.jpg
# ../data/train/04a47965e.jpg
# ../data/train/04b7f3a15.jpg
# ../data/train/04f906b5d.jpg
# ../data/train/04fe56fd3.jpg
# ../data/train/05522807e.jpg
# ../data/train/0573ed37c.jpg
# ../data/train/059125072.jpg
# ../data/train/0594af5a7.jpg
# ../data/train/05c6591ee.jpg
# ../data/train/05cd43275.jpg
# ../data/train/05dfa9bb1.jpg
# ../data/train/05e946e1f.jpg
# ../data/train/060543bbf.jpg
# ../data/train/060740e25.jpg
# ../data/train/060c572e4.jpg
# ../data/train/06152e5bf.jpg
# ../data/train/0679b8bab.jpg
# ../data/train/06812a4fc.jpg
# ../data/train/069719eab.jpg
# ../data/train/06a78c36e.jpg
# ../data/train/06b42df4e.jpg
# ../data/train/06fdd4941.jpg
# ../data/train/073d83544.jpg
# ../data/train/07479da31.jpg
# ../data/train/077ba8cca.jpg
# ../data/train/0785826af.jpg
# ../data/train/0787635a2.jpg
# ../data/train/078d5b8b9.jpg
# ../data/train/07a4d2b9e.jpg
# ../data/train/07d6634c4.jpg
# ../data/train/07dc460bc.jpg
# ../data/train/07ebc6045.jpg
# ../data/train/08568d66f.jpg
# ../data/train/085d0d511.jpg
# ../data/train/086b6a39d.jpg
# ../data/train/0874422e6.jpg
# ../data/train/0877092cc.jpg
# ../data/train/088d3df51.jpg
# ../data/train/08a65db34.jpg
# ../data/train/08aa26ac1.jpg
# ../data/train/0923194d6.jpg
# ../data/train/09539e132.jpg
# ../data/train/09798007b.jpg
# ../data/train/097af10ac.jpg
# ../data/train/0989b2627.jpg
# ../data/train/099c4c2b9.jpg
# ../data/train/09b2de97e.jpg
# ../data/train/09d50b59d.jpg
# ../data/train/09eb21d04.jpg
# ../data/train/09f97e0cf.jpg
# ../data/train/0a029eead.jpg
# ../data/train/0a10cd864.jpg
# ../data/train/0a3cb453f.jpg
# ../data/train/0a3ff84a7.jpg
# ../data/train/0a7338e6f.jpg
# ../data/train/0a73f8a0f.jpg
# ../data/train/0a97d54ae.jpg
# ../data/train/0abbdee70.jpg
# ../data/train/0abc443ae.jpg
# ../data/train/0aef2f67e.jpg
# ../data/train/0afdb91a2.jpg
# ../data/train/0b47876ec.jpg
# ../data/train/0b5b60131.jpg
# ../data/train/0b7712f7a.jpg
# ../data/train/0b9624bd4.jpg
# ../data/train/0ba2166af.jpg
# ../data/train/0bb1adbd8.jpg
# ../data/train/0bb98c55d.jpg
# ../data/train/0bbb17b82.jpg
# ../data/train/0bff84dd0.jpg
# ../data/train/0c264c98e.jpg
# ../data/train/0c3d9007c.jpg
# ../data/train/0ca410614.jpg
# ../data/train/0cbb43d45.jpg
# ../data/train/0cbcaf240.jpg
# ../data/train/0cbe3f32c.jpg
# ../data/train/0cca0ffc8.jpg
# ../data/train/0ce3a22a3.jpg
# ../data/train/a76360ece.jpg
# ../data/train/a7e2015b3.jpg
# ../data/train/a81f68e82.jpg
# ../data/train/a88930f1f.jpg
# ../data/train/a8b61f66a.jpg
# ../data/train/a8cd65e4f.jpg
# ../data/train/a90339a28.jpg
# ../data/train/a93fe47af.jpg
# ../data/train/a94964eda.jpg
# ../data/train/a94d39f89.jpg
# ../data/train/a9913b99c.jpg
# ../data/train/a9cd1638c.jpg
# ../data/train/aa93e44f2.jpg
# ../data/train/ab9e2d432.jpg
# ../data/train/ac891ac35.jpg
# ../data/train/ad3fea21b.jpg
# ../data/train/ad67b76a3.jpg
# ../data/train/ad6e9eea2.jpg
# ../data/train/aeb9f155b.jpg
# ../data/train/aec95891a.jpg
# ../data/train/aedca9e2e.jpg
# ../data/train/af13ca6bc.jpg
# ../data/train/af1507e03.jpg
# ../data/train/af785ce1e.jpg
# ../data/train/af7f4eb72.jpg
# ../data/train/afe4fd4f5.jpg
# ../data/train/b030ec7d3.jpg
# ../data/train/b04239da0.jpg
# ../data/train/b0a22c629.jpg
# ../data/train/b0a32bf24.jpg
# ../data/train/b0caf416d.jpg
# ../data/train/b1341e5ff.jpg
# ../data/train/b21ca086c.jpg
# ../data/train/b26aeda3c.jpg
# ../data/train/b2f2a5dfd.jpg
# ../data/train/b30d051ab.jpg
# ../data/train/b35fb3de5.jpg
# ../data/train/b3822b5cd.jpg
# ../data/train/b3c320e1b.jpg
# ../data/train/b3d2304bf.jpg
# ../data/train/b3e72b002.jpg
# ../data/train/b45096c1e.jpg
# ../data/train/b53afdf5c.jpg
# ../data/train/b59778e6b.jpg
# ../data/train/b5a90214f.jpg
# ../data/train/b5e726c10.jpg
# ../data/train/b5e7db94b.jpg
# ../data/train/b61ff5016.jpg
# ../data/train/b628691a2.jpg
# ../data/train/b6324ea82.jpg
# ../data/train/b6b899073.jpg
# ../data/train/b6f8a915e.jpg
# ../data/train/b70d3e890.jpg
# ../data/train/b75c3bb71.jpg
# ../data/train/b7c9166b6.jpg
# ../data/train/b844b0d4f.jpg
# ../data/train/b900ef546.jpg
# ../data/train/b922186af.jpg
# ../data/train/b95e8d11b.jpg
# ../data/train/b9bffd5e2.jpg
# ../data/train/ba290b964.jpg
# ../data/train/ba3404681.jpg
# ../data/train/bb67d5c2e.jpg
# ../data/train/bb808af6f.jpg
# ../data/train/bbf57e28b.jpg
# ../data/train/bd20bc5c9.jpg
# ../data/train/bd5cb3bc5.jpg
# ../data/train/bd68a3064.jpg
# ../data/train/be589b720.jpg
# ../data/train/be9f01839.jpg
# ../data/train/bebf1704f.jpg
# ../data/train/bf697b8c4.jpg
# ../data/train/c00c660fc.jpg
# ../data/train/c0bc8d9f2.jpg
# ../data/train/c0e168cd3.jpg
# ../data/train/c1577d6ff.jpg
# ../data/train/c164bb5bb.jpg
# ../data/train/c20958f55.jpg
# ../data/train/c25cf1f92.jpg
# ../data/train/c2b7f1929.jpg
# ../data/train/c31bf0e39.jpg
# ../data/train/c34dd05a3.jpg
# ../data/train/c354a54ac.jpg
# ../data/train/c35743243.jpg
# ../data/train/c3e712a5d.jpg
# ../data/train/c3fa071f6.jpg
# ../data/train/c434ccb01.jpg
# ../data/train/c47a1b214.jpg
# ../data/train/c4dc3c575.jpg
# ../data/train/c631c7fdb.jpg
# ../data/train/c6b4933f7.jpg
# ../data/train/c74db0380.jpg
# ../data/train/c7b9b6d62.jpg
# ../data/train/c7c00c1a3.jpg
# ../data/train/c7df66915.jpg
# ../data/train/c87c9e9b2.jpg
# ../data/train/c88f6408f.jpg
# ../data/train/c8909d7a1.jpg
# ../data/train/c89aed93e.jpg
# ../data/train/c8b81529c.jpg
# ../data/train/c9175cfdd.jpg
# ../data/train/c9a573b93.jpg
# ../data/train/cab50874d.jpg
# ../data/train/cb256df87.jpg
# ../data/train/cb3236ed5.jpg
# ../data/train/cbab952fe.jpg
# ../data/train/cbfd50139.jpg
# ../data/train/cc1a14dfc.jpg
# ../data/train/cc4d168f6.jpg
# ../data/train/ccd16cf61.jpg
# ../data/train/cce5cb631.jpg
# ../data/train/ccf2bea3e.jpg
# ../data/train/cd243b0b0.jpg
# ../data/train/cdc68ad10.jpg
# ../data/train/cdd3bc83b.jpg
# ../data/train/ce4124be0.jpg
# ../data/train/ce69098f5.jpg
# ../data/train/cf0401699.jpg
# ../data/train/cf3a2a32d.jpg
# ../data/train/cf3adb4de.jpg
# ../data/train/d025ff56c.jpg
# ../data/train/d0ca0d7a0.jpg
# ../data/train/d136f8db2.jpg
# ../data/train/d13e3ffce.jpg
# ../data/train/d19c0b3c9.jpg
# ../data/train/d2265cb91.jpg
# ../data/train/d25b61e9f.jpg
# ../data/train/d2ae1e503.jpg
# ../data/train/d3b4a0cdf.jpg
# ../data/train/d43e719c7.jpg
# ../data/train/d474f39c8.jpg
# ../data/train/d4949ae24.jpg
# ../data/train/d4abcc41e.jpg
# ../data/train/d5943ea17.jpg
# ../data/train/d606fe447.jpg
# ../data/train/d623a5d12.jpg
# ../data/train/d6d425855.jpg
# ../data/train/d6d7c33f9.jpg
# ../data/train/d8ea34c21.jpg
# ../data/train/d93838526.jpg
# ../data/train/d94a7f88a.jpg
# ../data/train/da3cfa3d4.jpg
# ../data/train/dac01a162.jpg
# ../data/train/dac6b76fc.jpg
# ../data/train/dacaf5c55.jpg
# ../data/train/dafa14917.jpg
# ../data/train/dbfd38b38.jpg
# ../data/train/dc75973ed.jpg
# ../data/train/dc7f9cee6.jpg
# ../data/train/dc9ac3f45.jpg
# ../data/train/dd5dd7c60.jpg
# ../data/train/dd744ebfd.jpg
# ../data/train/ddc160ce0.jpg
# ../data/train/ddce42b64.jpg
# ../data/train/de544d27c.jpg
# ../data/train/de6f7f6c1.jpg
# ../data/train/de941b2fc.jpg
# ../data/train/df53b43f1.jpg
# ../data/train/dffff7fe4.jpg
# ../data/train/e081e431a.jpg
# ../data/train/e11b95f4e.jpg
# ../data/train/e1427550f.jpg
# ../data/train/e14f4de23.jpg
# ../data/train/e18bbfc52.jpg
# ../data/train/e1ddcee1f.jpg
# ../data/train/e1e3b78ab.jpg
# ../data/train/e1f6c91bb.jpg
# ../data/train/e2251ed47.jpg
# ../data/train/e2a3ba358.jpg
# ../data/train/e2e13ad15.jpg
# ../data/train/e2e2b0975.jpg
# ../data/train/e321272b3.jpg
# ../data/train/e344e8213.jpg
# ../data/train/e3471d3c2.jpg
# ../data/train/e46378032.jpg
# ../data/train/e4c9b3866.jpg
# ../data/train/e596e6bb2.jpg
# ../data/train/e5ab88ff3.jpg
# ../data/train/e6277ce7c.jpg
# ../data/train/e64e1c77b.jpg
# ../data/train/e6b5e296d.jpg
# ../data/train/e6cffbb3d.jpg
# ../data/train/e84d2bbd1.jpg
# ../data/train/e84e8709a.jpg
# ../data/train/e88d43ec5.jpg
# ../data/train/e92e52948.jpg
# ../data/train/e9491d2d6.jpg
# ../data/train/ea04b734a.jpg
# ../data/train/ea65602e0.jpg
# ../data/train/eb254c87a.jpg
# ../data/train/eb256e6be.jpg
# ../data/train/eba970515.jpg
# ../data/train/ebaa9b7d6.jpg
# ../data/train/ec2098ac5.jpg
# ../data/train/ecd58cc0a.jpg
# ../data/train/ecf19610a.jpg
# ../data/train/ed168fff1.jpg
# ../data/train/ed36e3b08.jpg
# ../data/train/ed59f37d2.jpg
# ../data/train/ed88cccdc.jpg
# ../data/train/edf831418.jpg
# ../data/train/efb3d3fb9.jpg
# ../data/train/efc4f0374.jpg
# ../data/train/efda9b4e7.jpg
# ../data/train/f04a71a47.jpg
# ../data/train/f04d9c252.jpg
# ../data/train/f05647ed3.jpg
# ../data/train/f05cd0112.jpg
# ../data/train/f1144b38d.jpg
# ../data/train/f1a038768.jpg
# ../data/train/f1a8585e0.jpg
# ../data/train/f1aaca96f.jpg
# ../data/train/f20ba2db5.jpg
# ../data/train/f244c9c23.jpg
# ../data/train/f24698e88.jpg
# ../data/train/f251e40f2.jpg
# ../data/train/f279ed35d.jpg
# ../data/train/f27d2e19c.jpg
# ../data/train/f2885d3d7.jpg
# ../data/train/f3089a3f2.jpg
# ../data/train/f3d0759c8.jpg
# ../data/train/f3ed7c4ee.jpg
# ../data/train/f438c0466.jpg
# ../data/train/f4c7f63e6.jpg
# ../data/train/f4f169106.jpg
# ../data/train/f54dedb60.jpg
# ../data/train/f54ff03a2.jpg
# ../data/train/f5607392f.jpg
# ../data/train/f5e0e61e4.jpg
# ../data/train/f5e3315ab.jpg
# ../data/train/f8d155138.jpg
# ../data/train/f8d848989.jpg
# ../data/train/f926234d6.jpg
# ../data/train/f9aabfc48.jpg
# ../data/train/fab41168b.jpg
# ../data/train/fb0a8b6b3.jpg
# ../data/train/fb804ab78.jpg
# ../data/train/fbc79aea4.jpg
# ../data/train/fc6860020.jpg
# ../data/train/fd151ae52.jpg
# ../data/train/fd95e2677.jpg
# ../data/train/fda2e0448.jpg
# ../data/train/fe0d6c114.jpg
# ../data/train/fe641f02e.jpg
# ../data/train/fe7ecb1f4.jpg
# ../data/train/feb78a8de.jpg
# ../data/train/ff1716939.jpg
# ../data/train/ff46aa8d4.jpg
# ../data/train/ffaa964a2.jpg
